# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/0a/93/c7bca39b23aae45cd2e85ad3871c81eccc63b9c5276e926511e2e5b0879d/tensorflow_gpu-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 37kB/s
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.34.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.10.0)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 51.7MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.2.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 59.1MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.28.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.18.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu) (46.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.2.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.21.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu) (2.10.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow-gpu) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=9ce607e1e4c8eb10613110946a5b7c6a2c391906a7e003f722d629722aa91cc5
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0rc2 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.1.1 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorflow-estimator<2.3.0,>=2.2.0rc0, but you'll have tensorflow-estimator 2.1.0 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, gast, tensorflow-gpu
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 tensorboard-2.1.1 tensorflow-estimator-2.1.0 tensorflow-gpu-2.1.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
device_name = tf.test.gpu_device_name()
if device_name!='/device:GPU:0':
  raise SystemError('GPU deivce not found')
print('Found GPU at:{}'.format(device_name))
# Out:
# Found GPU at:/device:GPU:0

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-02b85537-f636-451a-a48e-7e577f044d4c" name="files[]" multiple disabled />
#      <output id="result-02b85537-f636-451a-a48e-7e577f044d4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving x_train.pickle to x_train.pickle
# Saving y_train.pickle to y_train.pickle

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import pickle

def preprocess_input(x):
    # Change BRG => RGB
    x = x[:, :, :, ::-1]

    # Normalize
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

x_train = pickle.load(open("x_train.pickle","rb"))
y_train = pickle.load(open("y_train.pickle","rb"))

BATCH_SIZE = 50
EPOCHS = 100
preprocess_input(x_train)


# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# and a logistic layer -- let's say we have 50 classes
predictions = Dense(50, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop',metrics=['accuracy'], loss='categorical_crossentropy')

# train the model on the new data for a few epochs
aug = ImageDataGenerator(rotation_range=20,
                         zoom_range=0.15,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.15,
                         horizontal_flip=True,
                         fill_mode="nearest")
model.fit_generator(aug.flow(x_train, y_train, batch_size=BATCH_SIZE),
                    steps_per_epoch=len(x_train) // BATCH_SIZE,
                    epochs=EPOCHS)

# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)

# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9),metrics=['accuracy'], loss='categorical_crossentropy')

# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
aug = ImageDataGenerator(rotation_range=20,
                         zoom_range=0.15,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.15,
                         horizontal_flip=True,
                         fill_mode="nearest")
model.fit_generator(aug.flow(x_train, y_train, batch_size=BATCH_SIZE),
                    steps_per_epoch=len(x_train) // BATCH_SIZE,
                    epochs=EPOCHS)
# Out:
# Using TensorFlow backend.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# Epoch 1/100
# 1/1 [==============================] - 10s 10s/step - loss: 3.9847 - accuracy: 0.0400
# Epoch 2/100
# 1/1 [==============================] - 0s 248ms/step - loss: 4.2714 - accuracy: 0.0600
# Epoch 3/100
# 1/1 [==============================] - 1s 747ms/step - loss: 4.8352 - accuracy: 0.0800
# Epoch 4/100
# 1/1 [==============================] - 1s 786ms/step - loss: 4.9850 - accuracy: 0.1000
# Epoch 5/100
# 1/1 [==============================] - 1s 797ms/step - loss: 4.5945 - accuracy: 0.1000
# Epoch 6/100
# 1/1 [==============================] - 1s 739ms/step - loss: 4.1860 - accuracy: 0.2200
# Epoch 7/100
# 1/1 [==============================] - 1s 764ms/step - loss: 3.7674 - accuracy: 0.1600
# Epoch 8/100
# 1/1 [==============================] - 1s 788ms/step - loss: 3.5560 - accuracy: 0.3000
# 1/1 [==============================] - 1s 802ms/step - loss: 1.0220 - accuracy: 0.6000
# Epoch 40/100
# 1/1 [==============================] - 1s 789ms/step - loss: 1.0864 - accuracy: 0.7200
# Epoch 41/100
# 1/1 [==============================] - 1s 786ms/step - loss: 1.1451 - accuracy: 0.6000
# Epoch 42/100
# 1/1 [==============================] - 1s 800ms/step - loss: 1.1808 - accuracy: 0.6400
# Epoch 43/100
# 1/1 [==============================] - 1s 822ms/step - loss: 1.1251 - accuracy: 0.6400
# Epoch 44/100
# 1/1 [==============================] - 1s 784ms/step - loss: 1.1504 - accuracy: 0.6400
# Epoch 45/100
# 1/1 [==============================] - 1s 787ms/step - loss: 1.1601 - accuracy: 0.5800
# Epoch 46/100
# 1/1 [==============================] - 1s 816ms/step - loss: 1.1536 - accuracy: 0.6200
# Epoch 47/100
# 1/1 [==============================] - 1s 793ms/step - loss: 1.1244 - accuracy: 0.6000
# Epoch 48/100
# 1/1 [==============================] - 1s 772ms/step - loss: 1.2590 - accuracy: 0.5600
# Epoch 49/100
# 1/1 [==============================] - 1s 717ms/step - loss: 1.1943 - accuracy: 0.5400
# Epoch 50/100
# 1/1 [==============================] - 1s 815ms/step - loss: 1.2469 - accuracy: 0.6200
# Epoch 51/100
# 1/1 [==============================] - 1s 792ms/step - loss: 1.3308 - accuracy: 0.5200
# Epoch 52/100
# 1/1 [==============================] - 1s 795ms/step - loss: 1.2203 - accuracy: 0.6000
# Epoch 53/100
# 1/1 [==============================] - 1s 790ms/step - loss: 1.1134 - accuracy: 0.6400
# Epoch 54/100
# 1/1 [==============================] - 1s 803ms/step - loss: 1.1437 - accuracy: 0.6400
# Epoch 55/100
# 1/1 [==============================] - 1s 808ms/step - loss: 1.0681 - accuracy: 0.7000
# Epoch 56/100
# 1/1 [==============================] - 1s 802ms/step - loss: 1.1781 - accuracy: 0.6200
# Epoch 57/100
# 1/1 [==============================] - 1s 776ms/step - loss: 1.1261 - accuracy: 0.6400
# Epoch 58/100
# 1/1 [==============================] - 1s 793ms/step - loss: 1.1019 - accuracy: 0.6000
# Epoch 59/100
# 1/1 [==============================] - 1s 800ms/step - loss: 1.1339 - accuracy: 0.5600
# Epoch 60/100
# 1/1 [==============================] - 1s 797ms/step - loss: 1.0720 - accuracy: 0.6200
# Epoch 61/100
# 1/1 [==============================] - 1s 779ms/step - loss: 1.0675 - accuracy: 0.7000
# Epoch 62/100
# 1/1 [==============================] - 1s 742ms/step - loss: 1.1160 - accuracy: 0.5800
# Epoch 63/100
# 1/1 [==============================] - 1s 763ms/step - loss: 1.2300 - accuracy: 0.6000
# Epoch 64/100
# 1/1 [==============================] - 1s 784ms/step - loss: 1.2324 - accuracy: 0.6000
# Epoch 65/100
# 1/1 [==============================] - 1s 719ms/step - loss: 1.3007 - accuracy: 0.5200
# Epoch 66/100
# 1/1 [==============================] - 1s 792ms/step - loss: 1.1530 - accuracy: 0.6200
# Epoch 67/100
# 1/1 [==============================] - 1s 757ms/step - loss: 1.0726 - accuracy: 0.6400
# Epoch 68/100
# 1/1 [==============================] - 1s 752ms/step - loss: 1.1385 - accuracy: 0.5800
# Epoch 69/100
# 1/1 [==============================] - 1s 779ms/step - loss: 1.0446 - accuracy: 0.6200
# Epoch 70/100
# 1/1 [==============================] - 1s 803ms/step - loss: 1.1781 - accuracy: 0.5600
# Epoch 71/100
# 1/1 [==============================] - 1s 795ms/step - loss: 1.1124 - accuracy: 0.6200
# Epoch 72/100
# 1/1 [==============================] - 1s 832ms/step - loss: 1.1122 - accuracy: 0.6800
# Epoch 73/100
# 1/1 [==============================] - 1s 789ms/step - loss: 1.1396 - accuracy: 0.5400
# Epoch 74/100
# 1/1 [==============================] - 1s 782ms/step - loss: 1.0941 - accuracy: 0.5800
# Epoch 75/100
# 1/1 [==============================] - 1s 767ms/step - loss: 0.9906 - accuracy: 0.6600
# Epoch 76/100
# 1/1 [==============================] - 1s 768ms/step - loss: 1.2318 - accuracy: 0.6000
# Epoch 77/100
# 1/1 [==============================] - 1s 781ms/step - loss: 1.1861 - accuracy: 0.5600
# Epoch 78/100
# 1/1 [==============================] - 1s 792ms/step - loss: 1.0244 - accuracy: 0.7000
# Epoch 79/100
# 1/1 [==============================] - 1s 771ms/step - loss: 1.2440 - accuracy: 0.5800
# Epoch 80/100
# 1/1 [==============================] - 1s 738ms/step - loss: 1.0664 - accuracy: 0.6200
# Epoch 81/100
# 1/1 [==============================] - 1s 781ms/step - loss: 1.2292 - accuracy: 0.5800
# Epoch 82/100
# 1/1 [==============================] - 1s 784ms/step - loss: 1.0302 - accuracy: 0.6200
# Epoch 83/100
# 1/1 [==============================] - 1s 773ms/step - loss: 1.0419 - accuracy: 0.6200
# Epoch 84/100
# 1/1 [==============================] - 1s 730ms/step - loss: 1.1626 - accuracy: 0.6200
# Epoch 85/100
# 1/1 [==============================] - 1s 785ms/step - loss: 1.1497 - accuracy: 0.6000
# Epoch 86/100
# 1/1 [==============================] - 1s 749ms/step - loss: 1.2172 - accuracy: 0.6000
# Epoch 87/100
# 1/1 [==============================] - 1s 761ms/step - loss: 1.0613 - accuracy: 0.6800
# Epoch 88/100
# 1/1 [==============================] - 1s 766ms/step - loss: 1.0643 - accuracy: 0.6400
# Epoch 89/100
# 1/1 [==============================] - 1s 738ms/step - loss: 1.1149 - accuracy: 0.5600
# Epoch 90/100
# 1/1 [==============================] - 1s 791ms/step - loss: 0.9598 - accuracy: 0.6800
# Epoch 91/100
# 1/1 [==============================] - 1s 767ms/step - loss: 1.1993 - accuracy: 0.5400
# Epoch 92/100
# 1/1 [==============================] - 1s 714ms/step - loss: 1.1391 - accuracy: 0.6800
# Epoch 93/100
# 1/1 [==============================] - 1s 783ms/step - loss: 1.0714 - accuracy: 0.6200
# Epoch 94/100
# 1/1 [==============================] - 1s 751ms/step - loss: 1.1727 - accuracy: 0.6000
# Epoch 95/100
# 1/1 [==============================] - 1s 750ms/step - loss: 1.0432 - accuracy: 0.6600
# Epoch 96/100
# 1/1 [==============================] - 1s 769ms/step - loss: 1.0161 - accuracy: 0.6800
# Epoch 97/100
# 1/1 [==============================] - 1s 748ms/step - loss: 1.0545 - accuracy: 0.6400
# Epoch 98/100
# 1/1 [==============================] - 1s 769ms/step - loss: 1.0482 - accuracy: 0.6400
# Epoch 99/100
# 1/1 [==============================] - 1s 743ms/step - loss: 1.0664 - accuracy: 0.6200
# Epoch 100/100
# 1/1 [==============================] - 1s 758ms/step - loss: 1.0727 - accuracy: 0.6000
